# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import torch
import glob
import pandas as pd

# %%
img = np.array(Image.open('../data/사전테스트데이터/0527_test1.png'))

# %%
fig = plt.figure(figsize = (10,10))
plt.imshow(img[1018:1082,961:1025,])
