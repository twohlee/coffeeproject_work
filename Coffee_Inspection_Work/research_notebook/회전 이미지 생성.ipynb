# %% [markdown]
# # 프로젝트 목표
# # - normal, broken, insect, black 이미지 데이터 회전 시켜서 1장당 총 5개 이미지씩 생성하기

# %% [markdown]
# # 모듈 가져오기

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import torch
import glob

# 필요한 모듈 가져오기
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pylab
plt.rcParams['figure.figsize'] = 10, 10
import plotly.offline as py
import plotly.graph_objs as go
# %matplotlib inline

# %% [markdown]
# # Normal Data

# %%
# 이미지 불러오기
img_list = list()
for take_num in range(1,15):
    take_list = list()
    for file_num in range(121):
        path = '/content/drive/My Drive/Coffee_Inspection/참고자료/real_data/normal_data/normal_sec_processed_data/20200518_' + str(file_num) + '_normal_take' + str(take_num) + '_final.jpg'
        img = np.array(Image.open(path))
        take_list.append(img)
    img_list.append(take_list)
# print(len(img_list))
# print(len(img_list[1]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-166e7d2a0e63> in <module>()
#       5     for file_num in range(121):
#       6         path = '/content/drive/My Drive/Coffee_Inspection/참고자료/real_data/normal_data/normal_sec_processed_data/20200518_' + str(file_num) + '_normal_take' + str(take_num) + '_final.jpg'
# ----> 7         img = np.array(Image.open(path))
#       8         take_list.append(img)
#       9     img_list.append(take_list)
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2816         exclusive_fp = True
#    2817
# -> 2818     prefix = fp.read(16)
#    2819
#    2820     preinit()
#
# KeyboardInterrupt:

# %%
# 필요한 모듈 설치하기
pip install torchgeometry==0.1.2

# %%
# 필요한 모듈 가져오기
import torchgeometry as tgm
