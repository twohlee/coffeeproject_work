# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
thres = 180
img = Image.open('../Models/20200604_test_three10_.png')
plt.imshow(np.array(img)[250:1550,200:1500])
plt.show()
